# %%
PROXY_BASE_URL = "https://lh-proxy.onrender.com"
# API_BASE_PREFIX = "/references"
API_VERSION = "/v1"
SECRET_SCOPE = "lufthansa_proxy"
PROXY_PASSWORD_KEY = "password"
PROXY_PASSWORD_VALUE = "DataIntelligence2026"

VOLUME_ROOT = "/Volumes/main/lufthansa_level3/staging_area"
DEFAULT_VER = "/tmp"

# Endpoints keys
EP_AIRPORTS = "airports"
EP_AIRPORT_CODE = "airport_code"
EP_COUNTRIES = "countries"
EP_COUNTRY_CODE = "country_code"
EP_CITIES = "cities"
EP_CITY_CODE = "city_code"
EP_AIRLINES = "airlines"
EP_AIRLINE_CODE = "airline_code"
EP_AIRCRAFT = "aircraft"
EP_AIRCRAFT_CODE = "aircraft_code"
EP_FLIGHTSTATUS_BY_ROUTE = "flightstatus_by_route"

# Endpoints values
ENDPOINTS = {
    EP_AIRPORTS: "/references/airports",
    EP_AIRPORT_CODE: "/references/airports/{airportCode}",
    EP_COUNTRIES: "/references/countries",
    EP_COUNTRY_CODE: "/references/countries/{countryCode}",
    EP_CITIES: "/references/cities",
    EP_CITY_CODE: "/references/cities/{cityCode}",
    EP_AIRLINES: "/references/airlines",
    EP_AIRLINE_CODE: "/references/airlines/{airlineCode}",
    EP_AIRCRAFT: "/references/aircraft",
    EP_AIRCRAFT_CODE: "/references/aircraft/{aircraftCode}",
    EP_FLIGHTSTATUS_BY_ROUTE: "/operations/flightstatus/route/{origin}/{destination}/{date}",
}


# ENDPOINTS = {
#     "airports": f"v1/references/airports",
#     "airport_code": f"v1/references/airports/{airportCode}",
#     "countries": f"v1/references/countries",
#     "country_code": f"v1/references/countries/{countryCode}",
#     "cities": f"v1/references/cities",
#     "city_code": f"v1/references/cities/{cityCode}",
#     "airlines": f"v1/references/airlines",
#     "airline_code": f"v1/references/airlines/{airlineCode}",
#     "aircraft": f"v1/references/aircraft",
#     "aircraft_code": f"v1/references/aircraft/{aircraftCode}",
#     "flightstatus_by_route": f"/operations/flightstatus/route/{origin}/{destination}/{date}"
# }
